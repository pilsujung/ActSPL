# %%
# preparation (calculate hash values of code units)
import os
import inspect
import hashlib
import time

fList = list()


def print_py_file_paths(folder_path):
    fList.clear()
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.py') and "Test" not in root:
                file_path = os.path.join(root, file)
                fList.append(file_path)


def hash_function(source_code):
    """
    Takes in the source code of a function as a string and returns the SHA-256 hash
    of the source code as a hexadecimal string.
    """
    hash_object = hashlib.sha256(source_code.encode())
    hex_dig = hash_object.hexdigest()
    return hex_dig


def hash_functions_in_file(file_path):
    """
    Takes in a file path and returns a dictionary mapping function names to their
    corresponding SHA-256 hash of source code.
    """
    function_hashes = {}

    with open(file_path, "rt", encoding="UTF-8") as f:
        source_code = f.read()
        file_name = file_path.split("\\")[-1]
        # Split source code by "def " to get each function's source code
        function_sources = source_code.split("def ")[1:]

        for function_source in function_sources:
            # Get the function name and source code
            function_name = function_source.split("(")[0]
            source_code = "def " + function_source

            # Hash the source code and store in the dictionary
            function_hash = hash_function(source_code)
            function_hashes[file_name + "\\" + function_name + "()"] = function_hash

    return function_hashes

dic = {}
diff = set()
def hash_diff(file_path):
    print_py_file_paths(file_path)

    for f in fList:
        #dic.update(hash_functions_in_file(f))
        res = hash_functions_in_file(f)
        for k, v in res.items():
                if k in dic.keys() and v != dic[k]:
                    diff.add(k)
                else:
                    dic[k] = v

s = time.time()

hash_diff('C:\\Users\\user\\Downloads\\CAD_SPL-master\\ver5_CAD_MODE')

#hash_diff('C:\\Users\\user\\Downloads\\CAD_SPL-master\\ver1_BASE_MODE')
#hash_diff('C:\\Users\\user\\Downloads\\CAD_SPL-master\\ver2_ToF_MODE')
#hash_diff('C:\\Users\\user\\Downloads\\CAD_SPL-master\\ver3_CAMERA_MODE')
#hash_diff('C:\\Users\\user\\Downloads\\CAD_SPL-master\\ver4_YOLO_MODE')

print(dic)
print(diff)
e = time.time()
print(e - s)
# Out:
# {'run5_CAD.py\\__init__()': '794cf82b8e5f0e4e8e86242695ea675cf1b7680a857bcbf219e73fee87036473', 'Actor.py\\take_cmd_from_planner()': '85b86a1725da8891dbc68d1bc46ec9773b5e442872a96d99c32e3ec214793f44', 'Actor.py\\change_cmd_is_safe()': '0a7e8373f90b3263c40ba6da36d1c39705d4a674efd6e5584752add585242a21', 'Actor.py\\change_cmd_for_drone()': 'e7da42f7169f3dc556c8012d24601afd4d80469a9d09493418e408bf16009b67', 'Actor.py\\send_to_actuator()': 'fb5914697c2956e04705983e07d60daadf303621c5e5607e36689dd89404c501', 'ObjectDetector.py\\detect_from_frame()': 'ff6e832d26948def94360f55d963ac6e31517ffc98af5de605d91e3adeeb04a9', 'Sensor.py\\take_data_from_sensor()': '748268ac76b0db6a3239cebc0555eedc0623189b3e145bc354e31b5d4ff1a778', 'Sensor.py\\change_data_to_info()': 'fd01bfd430805eaea8544485fc2e0c6ec6d4b9a7b8762c1642a302bd98b76a5f', 'Sensor.py\\save_to_planner()': 'a80e34614fb5c091db07e8e1d3d6ce236fc4fb201741c9be1b22936b2a910eac', 'ValueChanger.py\\change_mm_to_cm()': '0e36002b47dff37a6be1de864179fb011c539243afc960812f71ab1d84f315cd', 'ValueChanger.py\\change_val_to_coor()': '24d52ce18954f784cada1bf57484dd2a270403fbdd0b62ecc66bb1823e1436f5', 'ValueChanger.py\\change_cmd_for_tello()': '27b790699327188b6118b9fc74fc9e15083e8af06128abdd06afc1ba168d1113', 'ValueChanger.py\\change_windows_to_window()': 'b11acaa010a45855494a1a4bb00665797767c34320c8a077fef569c82954fee9', 'ValueChanger.py\\change_to_safe_cmd()': 'a6181a537629c3eb3ff0d8f69296b299603cdffaac9aa7b4b6b8431d9f89836f', 'ValueChecker.py\\is_tof_val()': 'c837f48496fe49c2b40c5c0c8c4d05b68d3128a745446877ad887a1f9bc5a5cf', 'ValueChecker.py\\is_sdk_val()': '5ea52a77cadca7dcad5981cf6a4013e43087965023efdac5108e4e8fbb537ea8', 'H264decoder.py\\decode()': '1a9996023a3cc1e2f4811c04678f2ef7c5bf56bbf6713383bb8712326194cecd', 'YOLOv5.py\\__init__()': '8b74a6a3769bc547fdaaec6be1c0bc2cd223bf71dd29978b13c61f617682f604', 'YOLOv5.py\\detect_from_frame()': '382b82ffa1058b6915b754bef2bf86a67c5c78de146abd2b2346e946e9cc5076', 'YOLOv5.py\\__calculate_ir_window_coor()': '4159dbbc723bd962ffc6befda35990a28f9b996e09e83093a724cc57107367c1', 'YOLOv5.py\\__score_frame()': 'dcb0559beddaa526e66eb54c0ae1936d1f9a4b4bb205849d8eedc7f0e7de45a6', 'Planner5.py\\__init__()': '059548dac616b1daa1544a55ab3471f1dfc4276228908b818776d469aba2ea7c', 'Planner5.py\\__func_planner()': '03ecc29de09285c1d21f335f799783b7640ce43d015d39f944d2679e71cfd298', 'Planner5.py\\__func_stay_connection()': '1deabfe96cf3579be3dc5a86b829931774b453cf08d7257b0bb62de77e5bd8fb', 'Planner5.py\\__func_request_tof()': 'e3ab2f1ee6b3346323120ec96bfdf55d10f830defa87fd354b6b231a49157ce1', 'Planner5.py\\__redraw_frame()': 'cf9667933ef4567f4fc3ee22bb6365db999e3d2a8f26d53475567bfa5a2933ab', 'Planner5.py\\__create_real_coor()': '6b033ccf41a122d5611fbcb750935b8243ac1481e9c5e34f5ccb86d12b41a0b5', 'Planner5.py\\__create_avd_cmd()': 'b049a8dcc94ea07a94e8b0b776e1645305a0c3f3503300b75cb841f2762f0830', 'Planner5.py\\pop_cmd_queue()': '557f384c08c6517e013304cc0501a36b9f615489b072aaae3d3ef2d4fb00faf3', 'Planner5.py\\insert_cmd_queue()': 'f3a973adb5aeb504adea824eda7b324ecab7f9d8050ff224aac9285b9212a98a', 'Planner5.py\\get_info_8889Sensor_tof()': '42af89feb61376642de588eb68dd947878de64e05fa3c8b68d516943ba85766a', 'Planner5.py\\set_info_8889Sensor_tof()': '7367a5a5e85ab6da9a3fee7cbb0a75ce0842643263b90a8170a263a03ae6a633', 'Planner5.py\\get_info_8889Sensor_cmd()': '7cc3e9b6d7773f707a7929c0b924bb2f619b18ed6723b39def5bcac99484ec9c', 'Planner5.py\\set_info_8889Sensor_cmd()': 'dd92214ff49d5dde577669bed0439a05255d9ab324f116ea870c9aff8eb1b373', 'Planner5.py\\get_info_11111Sensor_frame()': '1c09a1698cc13773b3e2faff712405f13f633ff943cb2325bb45d658767bfe8c', 'Planner5.py\\set_info_11111Sensor_frame()': '438a2b69acd8350590e528b709782892094ddbf3cbe5be0466f63773a4c10d9c', 'Planner5.py\\get_info_11111Sensor_image()': '252e5cb29deb35fbf611c16e1cb30932f0ab6cd2379b24949ce1c7cafa7ce244', 'Planner5.py\\set_info_11111Sensor_image()': '82a523c8cdd1f335c3ad6aa276865b29f9013d1534bf632d66f91ee1e1834805', 'Planne ...
# set()
# 0.029005050659179688

# %%
## Preparation phase (instrumentation) ##
import os
import ast
import time


def getAllFilePathsFromDir(folder_path):
    fList = list()
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.py'):
                file_path = os.path.join(root, file)
                fList.append(file_path)
    return fList

def instrument(file_path):
    with open(file_path, "rt", encoding="UTF-8") as f:
        code = f.read()
        tree = ast.parse(code)
        
        for node in ast.walk(tree):
            if isinstance(node, ast.FunctionDef):
                # Get the function name
                function_name = node.name
                # Create a new print statement node
                print_node = ast.parse(f'print("Function Name:", "{function_name}")').body[0]
                # Insert the print statement at the beginning of the function body
                node.body.insert(0, print_node)
        
    return ast.unparse(tree)

s = time.time()
paths = getAllFilePathsFromDir('C:\\Users\\user\\Downloads\\CAD_SPL-master\\ver5_CAD_MODE')

for f in paths:
    new_code = instrument(f)
    print(new_code)

e = time.time()
print(e-s)
# Out:
# import threading
# import sys
# import socket
# from CAD.Plan.Planner5 import Planner
# from CAD.Tello.Tello8889Sensor import Tello8889Sensor
# from CAD.Tello.Tello11111Sensor import Tello11111Sensor
# from CAD.Tello.Tello8889Actor import Tello8889Actor
# from CAD.Test.TelloVirtualController import TelloVirtualController
# "\n- Architecture: Sense - Plan - Act Pattern\n\n- 입력방식(유선, 무선 및 포트)에 따라 Sense 계열 클래스 생성\n- 연산을 담당하는 Planner 클래스 생성\n- 출력방식(유선, 무선 및 포트)에 따라 Act 계열 클래스 생성\n\n- Sense 계열 클래스들은 \n    1) 데이터를 가져오고'\n    2) 데이터를 Planner가 받아들일 수 있는 정보로 변경하고V2\n    3) Planner에 저장\n    \n- Planner 클래스는\n    1) 저장된 값을 원하는 정보로 가공(3차원 좌표값으로 변경)하고\n    2) 가공한 정보를 바탕으로 회피 명령을 생성하고  n /\n    3) 생성된 명령을 Planner 내부에 저장\n    \n- Act 계열 클래스들은 \n    1) Planner에 저장된 값을 가져와서\n    2) Drone이 이해할 수 있는 값으로 변경하고\n    2) Actuator로 전송\n\n- 이 모든 과정은 순차적이 아닌 병렬적으로 수행(사용자 명령이 존재하기 때문)\n"
#
# class Main:
#
#     def __init__(self):
#         print('Function Name:', '__init__')
#         print('>>> 프로그램 준비중...')
#         self.stop_event = threading.Event()
#         self.tello_address = ('192.168.10.1', 8889)
#         self.is_takeoff = False
#         print('드론 연결 대기중...')
#         self.socket8889 = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
#         self.socket8889.bind(('', 8889))
#         self.socket8889.sendto('command'.encode('utf-8'), self.tello_address)
#         (response, addr) = self.socket8889.recvfrom(1024)
#         print('8889 port connect: {} ({})'.format(response, addr))
#         self.socket8889.sendto('streamon'.encode('utf-8'), self.tello_address)
#         (response, addr) = self.socket8889.recvfrom(1024)
#         print('video stream on: {} ({})'.format(response, addr))
#         self.socket8889.sendto('motoron'.encode('utf-8'), self.tello_address)
#         (response, addr) = self.socket8889.recvfrom(1024)
#         print('motor on: {} ({})'.format(response, addr))
#         self.socket11111 = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
#         self.socket11111.bind(('', 11111))
#         print('드론 연결 완료')
#         self.planner = Planner(self)
#         self.tello8889sensor = Tello8889Sensor(self)
#         self.tello11111sensor = Tello11111Sensor(self)
#         self.tello8889actor = Tello8889Actor(self)
#         self.virtual_controller = TelloVirtualController(self)
#         print('>>> 프로그램 실행')
#         self.virtual_controller.root.mainloop()
# if __name__ == '__main__':
#     version = sys.version.split('.')
#     if version[0] == '3' and version[1] == '9':
#         Main()
#     else:
#         print('>>>파이썬 3.9만 지원됩니다.')
#         print('>>>현재 버젼: {}'.format(sys.version))
#     print('>>> 프로그램 종료')
#
# from abc import *
#
# class Actor(metaclass=ABCMeta):
#
#     @abstractmethod
#     def take_cmd_from_planner(self):
#         print('Function Name:', 'take_cmd_from_planner')
#         '\n        Planner로부터 cmd를 가져온다\n        '
#         pass
#
#     @abstractmethod
#     def change_cmd_is_safe(self):
#         print('Function Name:', 'change_cmd_is_safe')
#         '\n        cmd가 충돌이 발생하지 않는 명령으로 변환한다\n        '
#         pass
#
#     @abstractmethod
#     def change_cmd_for_drone(self):
#         print('Function Name:', 'change_cmd_for_drone')
#         '\n        cmd를 Drone이 이해할 수 있는 cmd로 변경한다\n        '
#         pass
#
#     @abstractmethod
#     def send_to_actuator(self):
#         print('Function Name:', 'send_to_actuator')
#         '\n        cmd를 Actuator에게 전송한다\n        '
#         pass
# from abc import *
# import numpy as np
#
# class ObjectDetector(metaclass=ABCMeta):
#
#     @abstractmethod
#     def detect_from_frame(self, frame: np.fromstring):
#         print('Function Name:', 'detect_from_frame')
#         '\n        frame에서 객체를 감지하고, 윈도우를 적용한 image 및 윈도우의 (좌상단좌표, 우하단좌표)좌표를 리턴 \n        '
#         pass
# from abc import *
#
# class Sensor(metaclass=ABCMeta):
#
#     @abstractmethod
#     def take_data_from_sensor(self):
#         print('Function Name:', 'take_data_from_sensor')
#         '\n        센서로부터 data를 가져온다\n        '
#         pass
#
#     @abstractmethod
#     def change_data_to_info(self):
#         print('Function Name:', 'change_data_to_info')
#         '\n        data를 Planner가 이해할 수 있는 info로 변경한다\n        '
#         pass
#
#     @abstractmethod
#     def save_to_planner(self):
#         print('Function Name:', 'save_to_planner')
#         '\n        info를 Planner에 저장한다\n        '
#         pass
#
# """
# 값을 변환하는 함수에 대한 모듈
# """
#
# def change_mm_to_cm(val: int):
#     print('Function Name:', 'change_mm_to_cm')
#     return int(val / 10)
#
# def change_val_to_coor(object_val):
#     print('Function Name:', 'change_val_to_coor')
#     '\n    -입력값 - object_val: (tof값[cm], 윈도우좌표[px], screen의 최대픽셀[px])\n    -리턴값 - object_coor: (tof값[cm], 물체 중앙 좌표[cm], 물체 길이[cm])\n\n    입력값인 object_val을 드론을 원점으로 한 3차원 좌표인 object_coor로 변환하여 리턴\n\n    ※좌표계 주의※\n    -윈도우 좌표계[px]: 좌상단이 (0,0) / 우측이 x의 +방향, 하단이 y의 +방향\n    -실제 좌표계[cm]: 영상의 중심이 (0,0) / 우측이 x의 +방향, 상단이 y의 +방향\n    '
#     c = -3
#     tof_val: int = object_val[0]
#     if tof_val is None:
#         return None
#     window_left_up_coor = object_val[1][0]
#     window_right_down_coor = object_val[1][1]
#     screen_size = object_val[2]
#     window_length_x = window_right_down_coor[0] - window_left_up_coor[0]
#     window_length_y = window_right_down_coor[1] - window_left_up_coor[1]
#     window_length = (window_length_x, window_length_y)
#     window_center_coor_x = (window_left_up_coor[0] + window_right_down_coor[0]) / 2
#     window_center_coor_y = (window_left_up_coor[1] + window_right_down_coor[1]) / 2
#     window_center_coor = (window_center_coor_x, window_center_coor_y)
#     screen_center_coor_x = screen_size[0] / 2
#     screen_center_coor_y = screen_size[1] / 2
#     screen_center_coor = (screen_center_coor_x, screen_center_coor_y)
#     window_center_coor_x_re = window_center_coor[0] - screen_center_coor[0]
#     window_center_coor_y_re = screen_center_coor[1] - window_center_coor[1]
#     window_center_coor_re = (window_center_coor_x_re, window_center_coor_y_re)
#     real_length_x = window_length[0] * (tof_val + c) / 960
#     real_length_y = window_length[1] * (tof_val + c) / 960
#     real_center_coor_x = window_center_coor_re[0] * (tof_val + c) / 960
#     real_center_coor_y = window_center_coor_re[1] * (tof_val + c) / 960
#     if real_length_x > 1000:
#         real_length_x = 1000
#     if real_length_y < 1000:
#         real_length_y = 1000
#     if real_center_coor_x > 1000:
#         real_center_coor_x = 1000
#     if real_center_coor_y > 1000:
#         real_center_coor_y = 1000
#     real_length = (real_length_x, real_length_y)
#     real_center_coor = (real_center_coor_x, real_center_coor_y)
#     object_coor = (tof_val, real_center_coor, real_length)
#     return object_coor
#
# def change_cmd_for_tello(cmd: str):
#     print('Function Name:', 'change_cmd_for_tello')
#     if cmd is None:
#         return None
#     cmd_list = cmd.split(' ')
#     if cmd_list[0] in ['forward', 'back', 'right', 'left', 'cw', 'ccw', 'up', 'down', 'stop']:
#         weight = int(float(cmd_list[1])) if cmd_list[0] != 'stop' and len(cmd_list) > 1 else 0
#         if weight > 100:
#             weight = 100
#         if weight < 60:
#             weight = 60
#         rc_cmd = None
#         if cmd_list[0] == 'forward':
#             rc_cmd = 'rc 0 {} 0 0'.format(weight)
#         elif cmd_list[0] == 'back':
#             rc_cmd = 'rc 0 {} 0 0'.format(-1 * weight)
#         elif cmd_list[0] == 'left':
#             rc_cmd = 'rc {} 0 0 0'.format(-1 * weight)
#         elif cmd_list[0] == 'right':
#             rc_cmd = 'rc {} 0 0 0'.format(weight)
#         elif cmd_list[0] == 'up':
#             rc_cmd = 'rc 0 0 {} 0'.format(weight)
#         elif cmd_list[0] == 'down':
#             rc_cmd = 'rc 0 0 {} 0'.format(-1 * weight)
#         elif cmd_list[0] == 'cw':
#             rc_cmd = 'rc 0 0 0 {}'.format(weight)
#         elif cmd_list[0] == 'ccw':
#             rc_cmd = 'rc 0 0 0 {}'.format(-1 * weight)
#         elif cmd_list[0] == 'stop':
#             rc_cmd = 'rc 0 0 0 0'
#         return rc_cmd.encode('utf-8')
#     else:
#         return cmd.encode('utf-8')
#
# def change_windows_to_window(window_coor_list: list, ir_left_up_coor: tuple, ir_right_down_coor: tuple):
#     print('Function Name:', 'change_windows_to_window')
#     '\n    입력값 - window_coor_list: 윈도우의 (좌상단좌표, 우하단좌표)들이 들어있는 리스트\n    입력값 - ir_left_up_coor: 적외선 윈도우의 좌상단좌표\n    입력값 - ir_right_down_coor: 적외선 윈도우의 우하단좌표\n    출력값 - (window_left_up_coor, window_right_down_coor): 생성된 윈도우의 (좌상단좌표, 우하단좌표)\n    #window_coor_list 내의 좌표들이 적외선 영역에 걸쳐있으면 남기고, 외부이면 제거\n    #적외선 영역에 걸친 윈도우들은 하나로 융합\n    #IR 영역이 감지범위 내인 경우만 실행됨\n    '
#     passing_windows = []
#     ir_left_x = ir_left_up_coor[0]
#     ir_right_x = ir_right_down_coor[0]
#     ir_up_y = ir_left_up_coor[1]
#     ir_down_y = ir_right_down_coor[1]
#     for window in window_coor_list:
#         window_left_up_coor = window[0]
#         window_right_down_coor = window[1]
#         window_left_x = window_left_up_coor[0]
#         window_right_x = window_right_down_coor[0]
#         window_up_y = window_left_up_coor[1]
#         window_down_y = window_right_down_coor[1]
#         if ir_left_x <= window_right_x and ir_right_x >= window_left_x and (ir_up_y <= window_down_y) and (ir_down_y >= window_up_y):
#             passing_windows.append(window)
#     fusion_window = None
#     if len(passing_windows) != 0:
#         fusion_window = passing_windows.pop()
#     for window in passing_windows:
#         fusion_window_left_up_coor = fusion_window[0]
#         fusion_window_right_down_coor = fusion_window[1]
#         fusion_window_left_x = fusion_window_left_up_coor[0]
#         fusion_window_right_x = fusion_window_right_down_coor[0]
#         fusion_window_up_y = fusion_window_left_up_coor[1]
#         fusion_window_down_y = fusion_window_right_down_coor[1]
#         window_left_up_coor = window[0]
#         window_right_down_coor = window[1]
#         window_left_x = window_left_up_coor[0]
#         window_right_x = window_right_down_coor[0]
#         window_up_y = window_left_up_coor[1]
#         window_down_y = window_right_down_coor[1]
#         if fusion_window_left_x <= window_right_x and fusion_window_right_x >= window_left_x and (fusion_window_up_y <= window_down_y) and (fusion_window_down_y >= window_up_y):
#             fusion_window_left_x = max(fusion_window_left_x, window_left_x)
#             fusion_window_right_x = max(fusion_window_right_x, window_right_x)
#             fusion_window_up_y = max(fusion_window_up_y, window_up_y)
#             fusion_window_down_y = max(fusion_window_down_y, window_down_y)
#             fusion_window_left_up_coor = (fusion_window_left_x, fusion_window_up_y)
#             fusion_window_right_down_coor = (fusion_window_right_x, fusion_window_down_y)
#             fusion_window = (fusion_window_left_up_coor, fusion_window_right_down_coor)
#     if fusion_window is None:
#         fusion_window_left_x = -131072
#         fusion_window_right_x = 131072
#         fusion_window_up_y = -131072
#         fusion_window_down_y = 131072
#         fusion_window_left_up_coor = (fusion_window_left_x, fusion_window_up_y)
#         fusion_window_right_down_coor = (fusion_window_right_x, fusion_window_down_y)
#         fusion_window = (fusion_window_left_up_coor, fusion_window_right_down_coor)
#     return fusion_window
#
# def change_to_safe_cmd(cmd: str, tof: int, threshold: int):
#     print('Function Name:', 'change_to_safe_cmd')
#     if cmd is None:
#         return None
#     cmd_list = cmd.split(' ')
#     if cmd_list[0] != 'forward':
#         return cmd
#     rest_safe_distance = tof - threshold
#     move_distance = int(cmd_list[1])
#     new_move_distance = rest_safe_distance - move_distance
#     if tof >= 1000:
#         new_move_distance = move_distance
#         return 'forward {}'.format(new_move_distance)
#     if new_move_distance < 20:
#         return 'stop'
#     return 'forward {}'.format(new_move_distance)
# """
# 값을 확인하는 함수에 대한 모듈
# """
#
# def is_tof_val(val: str):
#     print('Function Name:', 'is_tof_val')
#     val_list = val.split()
#     if val_list[0] == 'tof' and val_list[-1].isdigit():
#         int_val = int(val_list[-1])
#         if 0 <= int_val <= 8192:
#             return True
#         else:
#             return False
#     else:
#         return False
#
# def is_sdk_val(val: str):
#     print('Function Name:', 'is_sdk_val')
#     '\n    Tello SDK 명령어의 첫 어절에는 숫자가 없음\n    '
#     first_part: str = val.split()[0]
#     for char in first_part:
#         if char.isdigit():
#             print('[is_sdk_val] val에서 숫자가 감지되었습니다.')
#             return False
#     return True
#
# from CAD.Decoder.h264_39 import h264decoder
# import numpy as np
# '\nH.264: 2003년에 발표된 동영상 표준 규격으로, 텔로에서도 사용\n'
#
# def decode(decoder: h264decoder, packet_data: bytes):
#     print('Function Name:', 'decode')
#     res_frame_list = []
#     frames = decoder.decode(packet_data)
#     for framedata in frames:
#         (frame, width, height, linesize) = framedata
#         if frame is not None:
#             frame = np.fromstring(frame, dtype=np.ubyte, count=len(frame), sep='')
#             frame = frame.reshape((height, int(linesize / 3), 3))
#             frame = frame[:, :width, :]
#             res_frame_list.append(frame)
#     return res_frame_list
#
# from CAD.Basemodel.ObjectDetector import ObjectDetector
# from CAD.Calculation import ValueChanger
# import torch
# import numpy as np
# from PIL import Image, ImageTk
# import cv2
#
# class YOLOv5(ObjectDetector):
#     """
#     객체인식을 담당하는 클래스(YOLOv5s 사용)
#     """
#
#     def __init__(self):
#         print('Function Name:', '__init__')
#         self.__model = torch.hub.load('CAD/ObjectDetector/yolov5', 'custom', path='CAD/ObjectDetector/yolov5s.pt', source='local')
#         self.__classes = self.__model.names
#         self.__device = 'cuda' if torch.cuda.is_available() else 'cpu'
#         print('>>>>>>GPU 사용:', self.__device)
#
#     def detect_from_frame(self, frame: np.fromstring, tof: int):
#         print('Function Name:', 'detect_from_frame')
#         '\n        frame에서 객체를 감지하고, 윈도우를 적용한 image와 윈도우 리턴\n        '
#         window_coor_list = []
#         (object_label_list, object_coor_list) = self.__score_frame(frame)
#         n = len(object_label_list)
#         (x_shape, y_shape) = (frame.shape[1], frame.shape[0])
#         for i in range(n):
#             row = object_coor_list[i]
#             if row[4] >= 0.2:
#                 (x1, y1, x2, y2) = (int(row[0] * x_shape), int(row[1] * y_shape), int(row[2] * x_shape), int(row[3] * y_shape))
#                 window_coor_list.append(((x1, y1), (x2, y2)))
#                 RGB = (0, 255, 0)
#                 cv2.rectangle(frame, (x1, y1), (x2, y2), RGB, 2)
#                 name = self.__classes[int(object_label_list[i])]
#                 text = '{}: ({},{}), ({},{})'.format(name, x1, y1, x2, y2)
#                 cv2.putText(frame, text, (x1, y1 - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.9, RGB, 2)
#         (ir_window_left_up_coor, ir_window_right_down_coor) = self.__calculate_ir_window_coor(tof, y_shape, x_shape)
#         fusion_window_coor = None
#         if ir_window_left_up_coor and ir_window_right_down_coor:
#             RGB = (255, 0, 0)
#             cv2.rectangle(frame, ir_window_left_up_coor, ir_window_right_down_coor, RGB, 5)
#             cv2.putText(frame, 'IR AREA', (ir_window_left_up_coor[0], ir_window_left_up_coor[1] - 20), cv2.FONT_ITALIC, 0.5, (255, 255, 255), 1)
#             fusion_window_coor = ValueChanger.change_windows_to_window(window_coor_list, ir_window_left_up_coor, ir_window_right_down_coor)
#             RGB = (0, 0, 255)
#             cv2.rectangle(frame, fusion_window_coor[0], fusion_window_coor[1], RGB, 5)
#         image = Image.fromarray(frame)
#         try:
#             image = ImageTk.PhotoImage(image)
#         except:
#             image = 'TEST'
#         if fusion_window_coor is None and tof and (tof < 50):
#             fusion_window_coor = ((0, 0), (x_shape, y_shape))
#         return (image, fusion_window_coor)
#
#     def __calculate_ir_window_coor(self, tof, height, width):
#         print('Function Name:', '__calculate_ir_window_coor')
#         if tof is None or tof > 60 or tof <= 3:
#             return (None, None)
#         x = tof - 3
#         screen_height = height
#         screen_width = width
#         ir_window_left_up_coor_y = None
#         ir_window_right_down_coor_y = None
#         ir_window_left_up_coor_x = None
#         ir_window_right_down_coor_x = None
#         height_length_fov = 0.758 * x
#         height_length_tof_start = 0.203 * x - 4.472
#         height_length_tof_end = 0.555 * x - 5.528
#         height_proportion_start = height_length_tof_start / height_length_fov
#         height_proportion_end = height_length_tof_end / height_length_fov
#         if height_proportion_start <= 0:
#             ir_window_left_up_coor_y = 0
#         else:
#             ir_window_left_up_coor_y = int(height_proportion_start * screen_height)
#         if height_proportion_end <= 0:
#             ir_window_right_down_coor_y = 0
#         else:
#             ir_window_right_down_coor_y = int(height_proportion_end * screen_height)
#         width_length_fov = 1.048 * x
#         width_length_tof_start = 0.348 * x + 0.528
#         width_length_tof_end = 0.7 * x - 0.528
#         width_proportion_start = width_length_tof_start / width_length_fov
#         width_proportion_end = width_length_tof_end / width_length_fov
#         if width_proportion_start <= 0:
#             ir_window_left_up_coor_x = 0
#         else:
#             ir_window_left_up_coor_x = int(width_proportion_start * screen_width)
#         if width_proportion_end <= 0:
#             ir_window_right_down_coor_x = 0
#         else:
#             ir_window_right_down_coor_x = int(width_proportion_end * screen_width)
#         ir_window_left_up_coor = (ir_window_left_up_coor_x, ir_window_left_up_coor_y)
#         ir_window_right_down_coor = (ir_window_right_down_coor_x, ir_window_right_down_coor_y)
#         return (ir_window_left_up_coor, ir_window_right_down_coor)
#
#     def __score_frame(self, frame):
#         print('Function Name:', '__score_frame')
#         self.__model.to(self.__device)
#         frame = [frame]
#         object_label_and_coor_list = self.__model(frame)
#         (labels, coors) = (object_label_and_coor_list.xyxyn[0][:, -1].cpu().numpy(), object_label_and_coor_list.xyxyn[0][:, :-1].cpu().numpy())
#         return (labels, coors)
#
# import threading
# import sys
# import traceback
# from time import sleep
# from CAD.Calculation import ValueChanger
# from CAD.ObjectDetector.YOLOv5 import YOLOv5
# from numpy import *
#
# class Planner:
#     """
#     연산을 담당하는 클래스
#     1) 거리 정보가 안전 거리 이내인 경우, 윈도우 정보(존재하는 경우)를 가져와서 물체의 실제 크기를 계산
#     2) 계산한 크기를 바탕으로 물체의 실제 크기에 대한 좌표값을 생성
#     3) 생성한 좌표값을 바탕으로 회피명령을 생성
#     4) 회피명령을 queue에 저장
#     """
#
#     def __init__(self, main):
#         print('Function Name:', '__init__')
#         self.__printc('생성')
#         self.stop_event = main.stop_event
#         self.socket8889 = main.socket8889
#         self.tello_address = main.tello_address
#         self.threshold_distance = 60
#         self.__main = main
#         self.base_move_distance = 60
#         self.safe_constant = 20
#         self.__cmd_queue = []
#         self.__info_8889Sensor_tof = None
#         self.__info_8889Sensor_cmd = None
#         self.__info_11111Sensor_frame = None
#         self.__info_11111Sensor_image = None
#         self.__info_11111Sensor_coor = None
#         if not hasattr(self.__main, 'test'):
#             self.__YOLOv5 = YOLOv5()
#         else:
#             self.__YOLOv5 = 'TEST'
#         self.__thr_planner = threading.Thread(target=self.__func_planner, daemon=True)
#         self.__thr_planner.start()
#         self.__thr_stay_connection = threading.Thread(target=self.__func_stay_connection, daemon=True)
#         self.__thr_stay_connection.start()
#         self.__thr_requset_tof = threading.Thread(target=self.__func_request_tof, daemon=True)
#         self.__thr_requset_tof.start()
#
#     def __func_planner(self):
#         print('Function Name:', '__func_planner')
#         self.__printf('실행', sys._getframe().f_code.co_name)
#         try:
#             while not self.stop_event.is_set() and (not hasattr(self.__main, 'virtual_controller')):
#                 self.__printf('대기중', sys._getframe().f_code.co_name)
#                 sleep(1)
#             self.__virtual_controller = self.__main.virtual_controller
#             while not self.stop_event.is_set():
#                 (frame, tof, object_coor) = self.__redraw_frame()
#                 if self.__main.is_takeoff and object_coor:
#                     screen_size = (frame.shape[1], frame.shape[0])
#                     real_coor = self.__create_real_coor(object_coor, tof, screen_size)
#                     self.__avd_cmd = self.__create_avd_cmd(real_coor)
#                     if len(self.__cmd_queue) < 3:
#                         self.insert_cmd_queue(self.__avd_cmd)
#                         self.insert_cmd_queue('stop')
#         except Exception as e:
#             self.__printf('ERROR {}'.format(e), sys._getframe().f_code.co_name)
#             print(traceback.format_exc())
#         self.__printf('종료', sys._getframe().f_code.co_name)
#         try:
#             self.__virtual_controller.onClose()
#         except Exception as e:
#             self.__printf('ERROR {}'.format(e), sys._getframe().f_code.co_name)
#             print(traceback.format_exc())
#
#     def __func_stay_connection(self):
#         print('Function Name:', '__func_stay_connection')
#         self.__printf('실행', sys._getframe().f_code.co_name)
#         '\n        Tello는 15초 이상 전달받은 명령이 없을시 자동 착륙하기 때문에,\n        이를 방지하기 위해 5초 간격으로 Tello에게 "command" 명령을 전송\n        '
#         try:
#             while not self.stop_event.is_set():
#                 self.socket8889.sendto('command'.encode(), self.tello_address)
#                 sleep(5)
#         except Exception as e:
#             self.__printf('ERROR {}'.format(e), sys._getframe().f_code.co_name)
#             print(traceback.format_exc())
#         self.__printf('종료', sys._getframe().f_code.co_name)
#         try:
#             self.__virtual_controller.onClose()
#         except Exception as e:
#             self.__printf('ERROR {}'.format(e), sys._getframe().f_code.co_name)
#             print(traceback.format_exc())
#
#     def __func_request_tof(self):
#         print('Function Name:', '__func_request_tof')
#         self.__printf('실행', sys._getframe().f_code.co_name)
#         '\n        Tello에게 0.2초 주기로 tof값 전송을 요청하는 스레드\n        '
#         try:
#             while not self.stop_event.is_set():
#                 self.socket8889.sendto('EXT tof?'.encode(), self.tello_address)
#                 sleep(0.2)
#         except Exception as e:
#             self.__printf('ERROR {}'.format(e), sys._getframe().f_code.co_name)
#             print(traceback.format_exc())
#         self.__printf('종료', sys._getframe().f_code.co_name)
#         try:
#             self.__virtual_controller.onClose()
#         except Exception as e:
#             self.__printf('ERROR {}'.format(e), sys._getframe().f_code.co_name)
#             print(traceback.format_exc())
#
#     def __redraw_frame(self):
#         print('Function Name:', '__redraw_frame')
#         frame = self.get_info_11111Sensor_frame()
#         tof = self.get_info_8889Sensor_tof()
#         if frame is not None and type(frame) != str and (type(self.__YOLOv5) != str) and (frame.size != 0):
#             (image, object_coor) = self.__YOLOv5.detect_from_frame(frame, tof)
#             self.set_info_11111Sensor_image(image)
#             self.set_info_11111Sensor_coor(object_coor)
#             return (frame, tof, object_coor)
#         return (None, None, None)
#
#     def __create_real_coor(self, object_coor, tof, screen_size):
#         print('Function Name:', '__create_real_coor')
#         object_val = (tof, object_coor, screen_size)
#         object_coor = ValueChanger.change_val_to_coor(object_val)
#         return object_coor
#
#     def __create_avd_cmd(self, real_coor: tuple):
#         print('Function Name:', '__create_avd_cmd')
#         '\n        -입력값 - object_coor: (tof값[cm], 물체중심의 가로좌표[cm], 물체중심의 세로좌표[cm], 물체의 가로길이[cm], 물체의 세로길이[cm])\n        -출력값 - avd_cmd: str (방향, 이동거리를 포함)\n        '
#         if real_coor is None or real_coor[0] > self.threshold_distance:
#             return None
#         tof_val = real_coor[0]
#         real_center_coor = real_coor[1]
#         real_length = real_coor[2]
#         horizontal_move = None
#         vertical_move = None
#         object_left_coor = real_center_coor[0] - real_length[0] // 2 - self.safe_constant
#         if object_left_coor < -100:
#             object_left_coor = -100
#         object_left_coor = -1 * object_left_coor
#         object_right_coor = real_center_coor[0] + real_length[0] // 2 + self.safe_constant
#         if object_right_coor > 100:
#             object_right_coor = 100
#         object_up_coor = real_center_coor[1] + real_length[1] // 2 + self.safe_constant
#         if object_up_coor > 100:
#             object_up_coor = 100
#         object_down_coor = real_center_coor[1] - real_length[1] // 2 - self.safe_constant
#         if object_down_coor < -100:
#             object_down_coor = -100
#         object_down_coor = -1 * object_down_coor
#         if object_left_coor < object_right_coor:
#             horizontal_move = -1 * object_left_coor
#         else:
#             horizontal_move = object_right_coor
#         if abs(horizontal_move) == 100:
#             horizontal_move = 0
#         if object_down_coor < object_up_coor:
#             vertical_move = -1 * object_down_coor
#         else:
#             vertical_move = object_up_coor
#         if abs(vertical_move) == 100:
#             vertical_move = 0
#         avd_cmd = None
#         if horizontal_move == 0 and vertical_move == 0:
#             avoid_distance = self.threshold_distance - tof_val
#             if avoid_distance < self.base_move_distance:
#                 avoid_distance = self.base_move_distance
#             avd_cmd = 'back {}'.format(avoid_distance)
#         elif horizontal_move == 0 and vertical_move != 0:
#             if vertical_move < 0:
#                 if abs(vertical_move) < self.base_move_distance:
#                     vertical_move = -1 * self.base_move_distance
#                 avd_cmd = 'down {}'.format(-1 * vertical_move)
#             else:
#                 if abs(vertical_move) < self.base_move_distance:
#                     vertical_move = self.base_move_distance
#                 avd_cmd = 'up {}'.format(vertical_move)
#         elif horizontal_move != 0 and vertical_move == 0:
#             if horizontal_move < 0:
#                 if abs(horizontal_move) < self.base_move_distance:
#                     horizontal_move = -1 * self.base_move_distance
#                 avd_cmd = 'left {}'.format(-1 * horizontal_move)
#             else:
#                 if abs(horizontal_move) < self.base_move_distance:
#                     horizontal_move = self.base_move_distance
#                 avd_cmd = 'right {}'.format(horizontal_move)
#         elif abs(horizontal_move) < abs(vertical_move):
#             if horizontal_move < 0:
#                 if abs(horizontal_move) < self.base_move_distance:
#                     horizontal_move = -1 * self.base_move_distance
#                 avd_cmd = 'left {}'.format(-1 * horizontal_move)
#             else:
#                 if abs(horizontal_move) < self.base_move_distance:
#                     horizontal_move = self.base_move_distance
#                 avd_cmd = 'right {}'.format(horizontal_move)
#         elif vertical_move < 0:
#             if abs(vertical_move) < self.base_move_distance:
#                 vertical_move = -1 * self.base_move_distance
#             avd_cmd = 'down {}'.format(-1 * vertical_move)
#         else:
#             if abs(vertical_move) < self.base_move_distance:
#                 vertical_move = self.base_move_distance
#             avd_cmd = 'up {}'.format(vertical_move)
#         return avd_cmd
#
#     def pop_cmd_queue(self):
#         print('Function Name:', 'pop_cmd_queue')
#         data = None
#         if len(self.__cmd_queue) > 0:
#             data = self.__cmd_queue.pop(0)
#         return data
#
#     def insert_cmd_queue(self, info):
#         print('Function Name:', 'insert_cmd_queue')
#         self.__cmd_queue.append(info)
#
#     def get_info_8889Sensor_tof(self):
#         print('Function Name:', 'get_info_8889Sensor_tof')
#         info = self.__info_8889Sensor_tof
#         return info
#
#     def set_info_8889Sensor_tof(self, info):
#         print('Function Name:', 'set_info_8889Sensor_tof')
#         self.__info_8889Sensor_tof = info
#
#     def get_info_8889Sensor_cmd(self):
#         print('Function Name:', 'get_info_8889Sensor_cmd')
#         info = self.__info_8889Sensor_cmd
#         return info
#
#     def set_info_8889Sensor_cmd(self, info):
#         print('Function Name:', 'set_info_8889Sensor_cmd')
#         self.__info_8889Sensor_cmd = info
#
#     def get_info_11111Sensor_frame(self):
#         print('Function Name:', 'get_info_11111Sensor_frame')
#         info = self.__info_11111Sensor_frame
#         return info
#
#     def set_info_11111Sensor_frame(self, info):
#         print('Function Name:', 'set_info_11111Sensor_frame')
#         self.__info_11111Sensor_frame = info
#
#     def get_info_11111Sensor_image(self):
#         print('Function Name:', 'get_info_11111Sensor_image')
#         info = self.__info_11111Sensor_image
#         return info
#
#     def set_info_11111Sensor_image(self, info):
#         print('Function Name:', 'set_info_11111Sensor_image')
#         self.__info_11111Sensor_image = info
#
#     def get_info_11111Sensor_coor(self):
#         print('Function Name:', 'get_info_11111Sensor_coor')
#         info = self.__info_11111Sensor_coor
#         return info
#
#     def set_info_11111Sensor_coor(self, info):
#         print('Function Name:', 'set_info_11111Sensor_coor')
#         self.__info_11111Sensor_coor = info
#
#     def __printc(self, msg: str):
#         print('Function Name:', '__printc')
#         print('[{}] {}'.format(self.__class__.__name__, msg))
#
#     def __printf(self, msg: str, fname: str):
#         print('Function Name:', '__printf')
#         self.__printc('[{}]: {}'.format(fname, msg))
#
# import sys
# from CAD.Basemodel.Sensor import Sensor
# from CAD.Decoder import H264decoder
# from CAD.Decoder.h264_39 import h264decoder
# import threading
# import traceback
# from time import sleep
#
# class Tello11111Sensor(Sensor):
#
#     def __init__(self, main):
#         print('Function Name:', '__init__')
#         self.__printc('생성')
#         self.__stop_event = main.stop_event
#         self.__main = main
#         self.__planner = main.planner
#         self.__socket = main.socket11111
#         self.__decoder = h264decoder.H264Decoder()
#         self.__packet_data = bytes()
#         self.__thr_sensor = threading.Thread(target=self.__func_sensor, daemon=True)
#         self.__thr_sensor.start()
#
#     def __func_sensor(self):
#         print('Function Name:', '__func_sensor')
#         self.__printf('실행', sys._getframe().f_code.co_name)
#         try:
#             while not self.__stop_event.is_set() and (not hasattr(self.__main, 'virtual_controller')):
#                 self.__printf('대기중', sys._getframe().f_code.co_name)
#                 sleep(1)
#             self.__virtual_controller = self.__main.virtual_controller
#             while not self.__stop_event.is_set():
#                 self.take_data_from_sensor()
#                 self.change_data_to_info()
#         except Exception as e:
#             self.__printf('ERROR {}'.format(e), sys._getframe().f_code.co_name)
#             print(traceback.format_exc())
#         self.__printf('종료', sys._getframe().f_code.co_name)
#         try:
#             self.__virtual_controller.onClose()
#         except Exception as e:
#             self.__printf('ERROR {}'.format(e), sys._getframe().f_code.co_name)
#             print(traceback.format_exc())
#
#     def take_data_from_sensor(self):
#         print('Function Name:', 'take_data_from_sensor')
#         '\n        센서로부터 data를 가져온다\n        '
#         data: bytes = self.__socket.recv(2048)
#         self.__packet_data += data
#
#     def change_data_to_info(self):
#         print('Function Name:', 'change_data_to_info')
#         '\n        data를 Planner가 이해할 수 있는 info로 변경한다\n        '
#         packet_data = self.__packet_data
#         if len(packet_data) != 1460:
#             for frame in H264decoder.decode(self.__decoder, packet_data):
#                 self.save_to_planner(frame)
#             self.__packet_data = bytes()
#
#     def save_to_planner(self, info):
#         print('Function Name:', 'save_to_planner')
#         '\n        info를 Planner에 저장한다\n        '
#         self.__planner.set_info_11111Sensor_frame(info)
#
#     def __printc(self, msg: str):
#         print('Function Name:', '__printc')
#         print('[{}] {}'.format(self.__class__.__name__, msg))
#
#     def __printf(self, msg: str, fname: str):
#         print('Function Name:', '__printf')
#         self.__printc('[{}]: {}'.format(fname, msg))
# from CAD.Basemodel.Actor import Actor
# from CAD.Calculation import ValueChanger
# from time import sleep
# import threading
# import sys
# import traceback
#
# class Tello8889Actor(Actor):
#     """
#     Tello 8889 port로 명령을 송신하는 클래스
#     """
#
#     def __init__(self, main):
#         print('Function Name:', '__init__')
#         self.__printc('생성')
#         self.__threshold_distance = 50
#         self.__pre_cmd = None
#         self.__stop_event = main.stop_event
#         self.__main = main
#         self.__tello_address = main.tello_address
#         self.__planner = main.planner
#         self.__socket = main.socket8889
#         self.__thr_actor = threading.Thread(target=self.__func_actor, daemon=True)
#         self.__thr_actor.start()
#
#     def __func_actor(self):
#         print('Function Name:', '__func_actor')
#         self.__printf('실행', sys._getframe().f_code.co_name)
#         try:
#             while not self.__stop_event.is_set() and (not hasattr(self.__main, 'virtual_controller')):
#                 self.__printf('대기중', sys._getframe().f_code.co_name)
#                 sleep(1)
#             self.__virtual_controller = self.__main.virtual_controller
#             pre_cnt = 0
#             while not self.__stop_event.is_set():
#                 sleep(0.3)
#                 cmd = self.take_cmd_from_planner()
#                 if cmd == self.__pre_cmd:
#                     pre_cnt += 1
#                 self.__pre_cmd = cmd
#                 if cmd is None or pre_cnt > 1:
#                     pre_cnt = 0
#                     cmd = 'stop'
#                     continue
#                 safe_cmd = cmd
#                 if hasattr(self.__planner, 'get_info_8889Sensor_tof'):
#                     safe_cmd = self.change_cmd_is_safe(cmd)
#                 drone_cmd = self.change_cmd_for_drone(safe_cmd)
#                 self.send_to_actuator(drone_cmd)
#         except Exception as e:
#             self.__printf('ERROR {}'.format(e), sys._getframe().f_code.co_name)
#             print(traceback.format_exc())
#         self.__printf('종료', sys._getframe().f_code.co_name)
#         try:
#             self.__virtual_controller.onClose()
#         except Exception as e:
#             self.__printf('ERROR {}'.format(e), sys._getframe().f_code.co_name)
#             print(traceback.format_exc())
#
#     def take_cmd_from_planner(self):
#         print('Function Name:', 'take_cmd_from_planner')
#         '\n        Planner로부터 cmd를 가져온다\n        '
#         cmd = self.__planner.pop_cmd_queue()
#         return cmd
#
#     def change_cmd_is_safe(self, cmd):
#         print('Function Name:', 'change_cmd_is_safe')
#         '\n        cmd가 충돌이 발생하지 않는 명령으로 변환한다\n        '
#         tof = self.__planner.get_info_8889Sensor_tof()
#         safe_cmd = ValueChanger.change_to_safe_cmd(cmd, tof, self.__threshold_distance)
#         return safe_cmd
#
#     def change_cmd_for_drone(self, cmd):
#         print('Function Name:', 'change_cmd_for_drone')
#         '\n        cmd를 Drone이 이해할 수 있는 cmd로 변경한다\n        '
#         drone_cmd = ValueChanger.change_cmd_for_tello(cmd)
#         return drone_cmd
#
#     def send_to_actuator(self, cmd):
#         print('Function Name:', 'send_to_actuator')
#         '\n        cmd를 Actuator에게 전송한다\n        '
#         if cmd is not None:
#             self.__socket.sendto(cmd, self.__tello_address)
#             decode_cmd = cmd.decode()
#             if decode_cmd in ['takeoff', 'land']:
#                 self.__main.is_takeoff = True if decode_cmd == 'takeoff' else False
#                 cnt = 0
#                 while self.__planner.get_info_8889Sensor_cmd() is None or cnt <= 5:
#                     self.__planner.__cmd_queue = []
#                     sleep(1)
#                     cnt += 1
#                 self.__planner.set_info_8889Sensor_cmd(None)
#
#     def __printc(self, msg: str):
#         print('Function Name:', '__printc')
#         print('[{}] {}'.format(self.__class__.__name__, msg))
#
#     def __printf(self, msg: str, fname: str):
#         print('Function Name:', '__printf')
#         self.__printc('[{}]: {}'.format(fname, msg))
# from CAD.Basemodel.Sensor import Sensor
# from CAD.Calculation import ValueChecker
# from CAD.Calculation import ValueChanger
# import threading
# import sys
# import traceback
# from time import sleep
#
# class Tello8889Sensor(Sensor):
#     """
#     Tello 8889 port로 명령을 수신하는 클래스
#     """
#
#     def __init__(self, main):
#         print('Function Name:', '__init__')
#         self.__printc('생성')
#         self.__stop_event = main.stop_event
#         self.__main = main
#         self.__planner = main.planner
#         self.__socket = main.socket8889
#         self.__thr_sensor = threading.Thread(target=self.__func_sensor, daemon=True)
#         self.__thr_sensor.start()
#
#     def __func_sensor(self):
#         print('Function Name:', '__func_sensor')
#         self.__printf('실행', sys._getframe().f_code.co_name)
#         try:
#             while not self.__stop_event.is_set() and (not hasattr(self.__main, 'virtual_controller')):
#                 self.__printf('대기중', sys._getframe().f_code.co_name)
#                 sleep(1)
#             self.__virtual_controller = self.__main.virtual_controller
#             while not self.__stop_event.is_set():
#                 data = self.take_data_from_sensor()
#                 info = self.change_data_to_info(data)
#                 self.save_to_planner(info)
#         except Exception as e:
#             self.__printf('ERROR {}'.format(e), sys._getframe().f_code.co_name)
#             print(traceback.format_exc())
#         self.__printf('종료', sys._getframe().f_code.co_name)
#         try:
#             self.__virtual_controller.onClose()
#         except Exception as e:
#             self.__printf('ERROR {}'.format(e), sys._getframe().f_code.co_name)
#             print(traceback.format_exc())
#
#     def take_data_from_sensor(self):
#         print('Function Name:', 'take_data_from_sensor')
#         '\n        센서로부터 data를 가져온다\n        '
#         data: bytes = self.__socket.recv(1024)
#         return data
#
#     def change_data_to_info(self, data: bytes):
#         print('Function Name:', 'change_data_to_info')
#         '\n        data를 Planner가 이해할 수 있는 info로 변경한다\n        '
#         info: str = data.decode('utf-8')
#         return info
#
#     def save_to_planner(self, info: str):
#         print('Function Name:', 'save_to_planner')
#         '\n        info를 Planner에 저장한다\n        '
#         if ValueChecker.is_tof_val(info):
#             info = ValueChanger.change_mm_to_cm(int(info.split()[-1]))
#             if info > 60:
#                 info = 1000
#             self.__planner.set_info_8889Sensor_tof(info)
#         else:
#             self.__planner.set_info_8889Sensor_cmd(info)
#             print('[Tello8889Sensor]', info)
#
#     def __printc(self, msg: str):
#         print('Function Name:', '__printc')
#         print('[{}] {}'.format(self.__class__.__name__, msg))
#
#     def __printf(self, msg: str, fname: str):
#         print('Function Name:', '__printf')
#         self.__printc('[{}]: {}'.format(fname, msg))
#
# import sys
# import tkinter
# import threading
# from PIL import ImageTk
# from time import sleep
# import traceback
#
# class TelloVirtualController:
#     """
#     가상의 컨트롤러를 의미하는 클래스
#     -GUI 화면을 띄움
#     -Tello의 ToF값을 화면에 출력
#     -YOLO의 감지화면을 화면에 출력
#     -키보드 및 화면의 버튼을 통해 Tello를 조작
#     -thread_stay_connection 스레드를 통해 지속적으로 Tello에게 "command" 메세지를 전달
#     -종료시 stop_event를 실행
#     """
#
#     def __init__(self, main):
#         print('Function Name:', '__init__')
#         self.__printc('생성')
#         self.__socket8889 = main.socket8889
#         self.__tello_address = main.tello_address
#         self.__planner = main.planner
#         self.__stop_event: threading.Event = main.stop_event
#         self.__thread_stop_event = threading.Event()
#         self.__cm = 50
#         self.__degree = 50
#         self.__renewal_tof_time = 0.3
#         self.root = tkinter.Tk()
#         self.root.geometry('-10+0')
#         self.root.wm_title('CAD TEST for RMTT')
#         self.root.wm_protocol('WM_DELETE_WINDOW', self.onClose)
#         self.__text_tof = tkinter.Label(self.root, text='ToF: None', font='Helvetica 10 bold')
#         self.__text_tof.pack(side='top')
#         self.__text_keyboard = tkinter.Label(self.root, justify='left', text='\n        W - Move Tello Up\t\t\tArrow Up - Move Tello Forward\n        S - Move Tello Down\t\t\tArrow Down - Move Tello Backward\n        A - Rotate Tello Counter-Clockwise\t\tArrow Left - Move Tello Left\n        D - Rotate Tello Clockwise\t\tArrow Right - Move Tello Right\n        ')
#         self.__text_keyboard.pack(side='top')
#         self.__panel_image = None
#         self.__btn_landing = tkinter.Button(self.root, text='Land', relief='raised', command=self.land)
#         self.__btn_landing.pack(side='bottom', fill='both', expand='yes', padx=10, pady=5)
#         self.__btn_takeoff = tkinter.Button(self.root, text='Takeoff', relief='raised', command=self.takeoff)
#         self.__btn_takeoff.pack(side='bottom', fill='both', expand='yes', padx=10, pady=5)
#         self.__keyboard_connection = tkinter.Frame(self.root, width=100, height=2)
#         self.__keyboard_connection.bind('<KeyPress-q>', self.on_keypress_q)
#         self.__keyboard_connection.bind('<KeyPress-w>', self.on_keypress_w)
#         self.__keyboard_connection.bind('<KeyPress-s>', self.on_keypress_s)
#         self.__keyboard_connection.bind('<KeyPress-a>', self.on_keypress_a)
#         self.__keyboard_connection.bind('<KeyPress-d>', self.on_keypress_d)
#         self.__keyboard_connection.bind('<KeyPress-Up>', self.on_keypress_up)
#         self.__keyboard_connection.bind('<KeyPress-Down>', self.on_keypress_down)
#         self.__keyboard_connection.bind('<KeyPress-Left>', self.on_keypress_left)
#         self.__keyboard_connection.bind('<KeyPress-Right>', self.on_keypress_right)
#         self.__keyboard_connection.pack(side='bottom')
#         self.__keyboard_connection.focus_set()
#         if hasattr(self.__planner, 'get_info_8889Sensor_tof'):
#             self.__thread_update_tof = threading.Thread(target=self.func_update_tof, daemon=True)
#             self.__thread_update_tof.start()
#         if hasattr(self.__planner, 'get_info_11111Sensor_frame'):
#             self.__thread_print_video = threading.Thread(target=self.func_print_video, daemon=True)
#             self.__thread_print_video.start()
#
#     def land(self):
#         print('Function Name:', 'land')
#         self.send_cmd('land')
#
#     def takeoff(self):
#         print('Function Name:', 'takeoff')
#         self.send_cmd('takeoff')
#
#     def on_keypress_q(self, event):
#         print('Function Name:', 'on_keypress_q')
#         self.__printm('Q', 'stop')
#         self.send_cmd('stop')
#
#     def on_keypress_w(self, event):
#         print('Function Name:', 'on_keypress_w')
#         self.__printm('W', 'up')
#         self.move('up', self.__cm)
#
#     def on_keypress_s(self, event):
#         print('Function Name:', 'on_keypress_s')
#         self.__printm('S', 'down')
#         self.move('down', self.__cm)
#
#     def on_keypress_a(self, event):
#         print('Function Name:', 'on_keypress_a')
#         self.__printr('A', 'CCW')
#         self.rotate('ccw', self.__degree)
#
#     def on_keypress_d(self, event):
#         print('Function Name:', 'on_keypress_d')
#         self.__printr('D', 'CW')
#         self.rotate('cw', self.__degree)
#
#     def on_keypress_up(self, event):
#         print('Function Name:', 'on_keypress_up')
#         self.__printm('UP', 'forward')
#         self.move('forward', self.__cm)
#
#     def on_keypress_down(self, event):
#         print('Function Name:', 'on_keypress_down')
#         self.__printm('DOWN', 'back')
#         self.move('back', self.__cm)
#
#     def on_keypress_left(self, event):
#         print('Function Name:', 'on_keypress_left')
#         self.__printm('LEFT', 'left')
#         self.move('left', self.__cm)
#
#     def on_keypress_right(self, event):
#         print('Function Name:', 'on_keypress_right')
#         self.__printm('RIGHT', 'right')
#         self.move('right', self.__cm)
#
#     def move(self, direction, distance):
#         print('Function Name:', 'move')
#         '\n        direction: up, down, forward, back, right, left\n        distance: 20~500 cm\n        '
#         self.send_cmd('{} {}'.format(direction, distance))
#
#     def rotate(self, direction, degree):
#         print('Function Name:', 'rotate')
#         '\n        direction: ccw, cw\n        degree: 0~360 degree\n        '
#         self.send_cmd('{} {}'.format(direction, degree))
#
#     def func_update_tof(self):
#         print('Function Name:', 'func_update_tof')
#         self.__printf('실행', sys._getframe().f_code.co_name)
#         try:
#             while not self.__thread_stop_event.is_set():
#                 tof = self.__planner.get_info_8889Sensor_tof()
#                 self.__text_tof.config(text='ToF: {} cm'.format(tof))
#                 sleep(self.__renewal_tof_time)
#         except Exception as e:
#             self.__printf('ERROR {}'.format(e), sys._getframe().f_code.co_name)
#             print(traceback.format_exc())
#         self.__printf('종료', sys._getframe().f_code.co_name)
#
#     def func_print_video(self):
#         print('Function Name:', 'func_print_video')
#         self.__printf('실행', sys._getframe().f_code.co_name)
#         try:
#             while not self.__thread_stop_event.is_set():
#                 image: ImageTk.PhotoImage = self.__planner.get_info_11111Sensor_image()
#                 if self.__panel_image is None:
#                     self.__panel_image: tkinter.Label = tkinter.Label(image=image)
#                     self.__panel_image.image = image
#                     self.__panel_image.pack(side='right', padx=10, pady=10)
#                 else:
#                     self.__panel_image.configure(image=image)
#                     self.__panel_image.image = image
#         except Exception as e:
#             self.__printf('ERROR {}'.format(e), sys._getframe().f_code.co_name)
#             print(traceback.format_exc())
#         self.__printf('종료', sys._getframe().f_code.co_name)
#
#     def send_cmd(self, msg: str):
#         print('Function Name:', 'send_cmd')
#         try:
#             self.insert_controller_queue(msg)
#             sleep(0.4)
#             self.insert_controller_queue('stop')
#         except Exception as e:
#             self.__printf('ERROR {}'.format(e), sys._getframe().f_code.co_name)
#             print(traceback.format_exc())
#
#     def insert_controller_queue(self, cmd):
#         print('Function Name:', 'insert_controller_queue')
#         self.__planner.insert_cmd_queue(cmd)
#
#     def onClose(self):
#         print('Function Name:', 'onClose')
#         self.__socket8889.sendto('land'.encode('utf-8'), self.__tello_address)
#         sleep(0.5)
#         self.__socket8889.sendto('motoroff'.encode('utf-8'), self.__tello_address)
#         sleep(0.5)
#         self.__thread_stop_event.set()
#         self.__printc('종료중... >> thread stop event 실행')
#         self.__stop_event.set()
#         self.__printc('종료중... >> global stop event 실행')
#         self.root.quit()
#         self.__printc('종료')
#         exit()
#
#     def __printc(self, msg: str):
#         print('Function Name:', '__printc')
#         print('[{}] {}'.format(self.__class__.__name__, msg))
#
#     def __printf(self, msg: str, fname: str):
#         print('Function Name:', '__printf')
#         self.__printc('[{}]: {}'.format(fname, msg))
#
#     def __printm(self, key: str, action: str):
#         print('Function Name:', '__printm')
#         self.__printc('KEYBOARD {}: {} {} cm'.format(key, action, self.__cm))
#
#     def __printr(self, key: str, action: str):
#         print('Function Name:', '__printr')
#         self.__printc('KEYBOARD {}: {} {} degree'.format(key, action, self.__degree))
#
# 0.045013427734375

# %%
## Selection phase (Preprocessing) ##

import os
import inspect
import hashlib
import time

fList = list()


def print_py_file_paths(folder_path):
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.py') :
                file_path = os.path.join(root, file)
                fList.append(file_path)
    print(len(fList))


def hash_function(source_code):
    """
    Takes in the source code of a function as a string and returns the SHA-256 hash
    of the source code as a hexadecimal string.
    """
    hash_object = hashlib.sha256(source_code.encode())
    hex_dig = hash_object.hexdigest()
    return hex_dig


def hash_functions_in_file(file_path):
    """
    Takes in a file path and returns a dictionary mapping function names to their
    corresponding SHA-256 hash of source code.
    """
    function_hashes = {}

    with open(file_path, "rt", encoding="UTF-8") as f:
        source_code = f.read()
        file_name = file_path.split("\\")[-1]
        file_name = file_name.split(".")[0]
        # Split source code by "def " to get each function's source code
        function_sources = source_code.split("def ")[1:]

        for function_source in function_sources:
            # Get the function name and source code
            function_name = function_source.split("(")[0]
            source_code = "def " + function_source

            # Hash the source code and store in the dictionary
            function_hash = hash_function(source_code)
            function_hashes[file_name + "\\" + function_name + "()"] = function_hash

    return function_hashes


s = time.time()
print_py_file_paths('C:\\Users\\user\\Downloads\\CAD_SPL-master\\ver5_CAD_MODE')

dic = dict()
for f in fList:
    dic.update(hash_functions_in_file(f))

print(dic)

e = time.time()
print(e - s)
# Out:
# 21
# {'run5_CAD\\__init__()': '794cf82b8e5f0e4e8e86242695ea675cf1b7680a857bcbf219e73fee87036473', 'Actor\\take_cmd_from_planner()': '85b86a1725da8891dbc68d1bc46ec9773b5e442872a96d99c32e3ec214793f44', 'Actor\\change_cmd_is_safe()': '0a7e8373f90b3263c40ba6da36d1c39705d4a674efd6e5584752add585242a21', 'Actor\\change_cmd_for_drone()': 'e7da42f7169f3dc556c8012d24601afd4d80469a9d09493418e408bf16009b67', 'Actor\\send_to_actuator()': 'fb5914697c2956e04705983e07d60daadf303621c5e5607e36689dd89404c501', 'ObjectDetector\\detect_from_frame()': 'ff6e832d26948def94360f55d963ac6e31517ffc98af5de605d91e3adeeb04a9', 'Sensor\\take_data_from_sensor()': '748268ac76b0db6a3239cebc0555eedc0623189b3e145bc354e31b5d4ff1a778', 'Sensor\\change_data_to_info()': 'fd01bfd430805eaea8544485fc2e0c6ec6d4b9a7b8762c1642a302bd98b76a5f', 'Sensor\\save_to_planner()': 'a80e34614fb5c091db07e8e1d3d6ce236fc4fb201741c9be1b22936b2a910eac', 'ValueChanger\\change_mm_to_cm()': '0e36002b47dff37a6be1de864179fb011c539243afc960812f71ab1d84f315cd', 'ValueChanger\\change_val_to_coor()': '24d52ce18954f784cada1bf57484dd2a270403fbdd0b62ecc66bb1823e1436f5', 'ValueChanger\\change_cmd_for_tello()': '27b790699327188b6118b9fc74fc9e15083e8af06128abdd06afc1ba168d1113', 'ValueChanger\\change_windows_to_window()': 'b11acaa010a45855494a1a4bb00665797767c34320c8a077fef569c82954fee9', 'ValueChanger\\change_to_safe_cmd()': 'a6181a537629c3eb3ff0d8f69296b299603cdffaac9aa7b4b6b8431d9f89836f', 'ValueChecker\\is_tof_val()': 'c837f48496fe49c2b40c5c0c8c4d05b68d3128a745446877ad887a1f9bc5a5cf', 'ValueChecker\\is_sdk_val()': '5ea52a77cadca7dcad5981cf6a4013e43087965023efdac5108e4e8fbb537ea8', 'H264decoder\\decode()': '1a9996023a3cc1e2f4811c04678f2ef7c5bf56bbf6713383bb8712326194cecd', 'YOLOv5\\__init__()': '8b74a6a3769bc547fdaaec6be1c0bc2cd223bf71dd29978b13c61f617682f604', 'YOLOv5\\detect_from_frame()': '382b82ffa1058b6915b754bef2bf86a67c5c78de146abd2b2346e946e9cc5076', 'YOLOv5\\__calculate_ir_window_coor()': '4159dbbc723bd962ffc6befda35990a28f9b996e09e83093a724cc57107367c1', 'YOLOv5\\__score_frame()': 'dcb0559beddaa526e66eb54c0ae1936d1f9a4b4bb205849d8eedc7f0e7de45a6', 'Planner5\\__init__()': '059548dac616b1daa1544a55ab3471f1dfc4276228908b818776d469aba2ea7c', 'Planner5\\__func_planner()': '03ecc29de09285c1d21f335f799783b7640ce43d015d39f944d2679e71cfd298', 'Planner5\\__func_stay_connection()': '1deabfe96cf3579be3dc5a86b829931774b453cf08d7257b0bb62de77e5bd8fb', 'Planner5\\__func_request_tof()': 'e3ab2f1ee6b3346323120ec96bfdf55d10f830defa87fd354b6b231a49157ce1', 'Planner5\\__redraw_frame()': 'cf9667933ef4567f4fc3ee22bb6365db999e3d2a8f26d53475567bfa5a2933ab', 'Planner5\\__create_real_coor()': '6b033ccf41a122d5611fbcb750935b8243ac1481e9c5e34f5ccb86d12b41a0b5', 'Planner5\\__create_avd_cmd()': 'b049a8dcc94ea07a94e8b0b776e1645305a0c3f3503300b75cb841f2762f0830', 'Planner5\\pop_cmd_queue()': '557f384c08c6517e013304cc0501a36b9f615489b072aaae3d3ef2d4fb00faf3', 'Planner5\\insert_cmd_queue()': 'f3a973adb5aeb504adea824eda7b324ecab7f9d8050ff224aac9285b9212a98a', 'Planner5\\get_info_8889Sensor_tof()': '42af89feb61376642de588eb68dd947878de64e05fa3c8b68d516943ba85766a', 'Planner5\\set_info_8889Sensor_tof()': '7367a5a5e85ab6da9a3fee7cbb0a75ce0842643263b90a8170a263a03ae6a633', 'Planner5\\get_info_8889Sensor_cmd()': '7cc3e9b6d7773f707a7929c0b924bb2f619b18ed6723b39def5bcac99484ec9c', 'Planner5\\set_info_8889Sensor_cmd()': 'dd92214ff49d5dde577669bed0439a05255d9ab324f116ea870c9aff8eb1b373', 'Planner5\\get_info_11111Sensor_frame()': '1c09a1698cc13773b3e2faff712405f13f633ff943cb2325bb45d658767bfe8c', 'Planner5\\set_info_11111Sensor_frame()': '438a2b69acd8350590e528b709782892094ddbf3cbe5be0466f63773a4c10d9c', 'Planner5\\get_info_11111Sensor_image()': '252e5cb29deb35fbf611c16e1cb30932f0ab6cd2379b24949ce1c7cafa7ce244', 'Planner5\\set_info_11111Sensor_image()': '82a523c8cdd1f335c3ad6aa276865b29f9013d1534bf632d66f91ee1e1834805', 'Planner5\\get_info_11111Sensor_coor()': '0507069418d6d57cead5ce5b6a61c9f9dcd6ca6cc0f773c92b9ac64d407bba5f', 'Planner5\\s ...
# 0.012006282806396484

# %%
# Selection phase (Test Case Selection)

# automatically obtained hash values
hDict = {'t1001':['89d21e694ca58e764db12b0d727b531e78e03655495e1ebb9f94bbbef0708be13'], 't1002':['3fa70809476707dee1f9fc4c2f37eed27fdb969c2f3ebdfb12d4f7c8055221e0'], 't1003':['d8b14d7878da2a82378d2d6d790c01d9d206bb13e176376602ff0347e4e75095'], 't1004':['9f51f1b63e310d0cff14c2a3512bacd79de071850392009705a30db7642664c2'], 't1005':['9be770fe5e98fea4a379a13b66cd1c36165d930cc5a6a1584e9bac625ff93d81'], 't1006':['14c30960c8b17993c7da54991af62b79c270b073f0075e58af1d01f4de6ab23d'], 't1007':['89d21394ca58e764db12b0d727b531e78e03655495e1ebb9f94bbbef0708be13'], 't1008':['0180ae596dd49cbf642b5fa73118a1ff9b59d6d030a37473d58f74c6cafccc7f'], 't1009':['6d099b24c6c8573197ee23f5a490a430fea49e7d6912c8bfbf5705d6534ac348'], 
         't1010':['3fa70809476707dee1f9fc4c2f37eed27fdb969c2f3ebdfb12d4f7c8055221e0'], 't1011':['9f51f1b63e310d0cff14c2a3512bacd79de071850392009705a30db7642664c2'], 't1012':['9be770fe5e98fea4a379a13b66cd1c36165d930cc5a6a1584e9bac625ff93d81'], 't1013':['14c30960c8b17993c7da54991af62b79c270b073f0075e58af1d01f4de6ab23d'], 't1014':['89d21394ca58e764db12b0d727b531e78e03655495e1ebb9f94bbbef0708be13'], 't1015':['0180ae596dd49cbf642b5fa73118a1ff9b59d6d030a37473d58f74c6cafccc7f'], 't1021':['64faae596dd49cbf642565f73118a1469b59d6d030a37473d58f74c6cafc3443'], 't1022':['6d099b24c6c8573197ee23f5a490a430fea49e7d6912c8bfbf5705d6534ac348'], 't1023':['557f384c08c6517e013304cc0501a36b9f615489b072aaae3d3ef2d4fb00faf3'], 
         't1024':['f3a973adb5aeb504adea824eda7b324ecab7f9d8050ff224aac9285b9212a98a'], 't1025':['7cc3e9b6d7773f707a7929c0b924bb2f619b18ed6723b39def5bcac99484ec9c'], 't1026':['dd92214ff49d5dde577669bed0439a05255d9ab324f116ea870c9aff8eb1b373'], 't1027':['c837f48496fe49c2b40c5c0c8c4d05b68d3128a745446877ad887a1f9bc5a5cf'], 't1028':['5ea52a77cadca7dcad5981cf6a4013e43087965023efdac5108e4e8fbb537ea8'], 't1029':['0e36002b47dff37a6be1de864179fb011c539243afc960812f71ab1d84f315cd'], 't1030':['24d52ce18954f784cada1bf57484dd2a270403fbdd0b62ecc66bb1823e1436f5'], 't1031':['27b790699327188b6118b9fc74fc9e15083e8af06128abdd06afc1ba168d1113'], 't1032':['b11acaa010a45855494a1a4bb00665797767c34320c8a077fef569c82954fee9'], 
         't2001':['64ddae596dd49cbf642565f73118a1469b59d6d030a37473d58f74c6cafc3443'], 't2002':['6d099b24c6c8573197e553f5a490a430fea49e7d6912c8bfbf5705d6534ac348'], 't2003':['a6181a537629c3eb3ff0d8f69296b299603cdffaac9aa7b4b6b8431d9f89836f'], 't2004':['42af89feb61376642de588eb68dd947878de64e05fa3c8b68d516943ba85766a'], 't3001':['64fa33596dd49cbf642565f73118a1469b59d6d030a37473d58f74c6cafc3443'], 't3002':['7367a5a5e85ab6da9a3fee7cbb0a75ce0842643263b90a8170a263a03ae6a633'], 't3003':['d786b6a9cfe354db661204cb14e1f6c539eaddca70cdd3beb0c54f61382954a1'], 't3004':['9a3fe3d2f83bdc97147e802acb8913354735c2777999c497e1548b0b639d3765'], 't3005':['0e36002b47dff37a6be1de864179fb011c5aa243afc960812f71ab1d84f315cd'], 
         't3006':['7266386e98c21a363846032c74a443aab5d1ad97a65f07e1d91c6ca8be789122'], 't3007':['1c09a1698cc13773b3e2faff712405f13f633ff943cb2325bb45d658767bfe8c'], 't3008':['438a2b69acd8350590e528b709782892094ddbf3cbe5be0466f63773a4c10d9c'], 't3009':['252e5cb29deb35fbf611c16e1cb30932f0ab6cd2379b24949ce1c7cafa7ce244'], 't3010':['82a523c8cdd1f335c3ad6aa276865b29f9013d1534bf632d66f91ee1e1834805'], 't4001':['1a9996023a3cc1e2f4811c04678f2ef7c5bf56bbf6713383bb8712326194cecd'], 't4002':['382b82ffa1058b6915b754bef2bf86a67c5c78de146abd2b2346e946e9cc5076'], 't4003':['d786b6a9cfe354db661ee4cb14e1f6c539eaddca70cdd3beb0c54f61382954a1'], 't4004':['9a3fe3d2f83bdc97147e802acb8913354115c2777999c497e1548b0b639d3765'], 
         't4005':['382b82ffa1058b6915b754bef2bf86a67c5c78de146abd2b2346e946e9cc5076'], 't4006':['4159dbbc723bd962ffc6befda35990a28f9b996e09e83093a724cc57107367c1']}
s = time.time()
sel = []
for k, v in hDict.items():
    if v[0] in dic.values():
        sel.append(k)
        print(k)

e = time.time()
print(e-s)
# Out:
# t1002
# t1004
# t1005
# t1006
# t1007
# t1008
# t1009
# t1010
# t1011
# t1012
# t1013
# t1014
# t1015
# t1022
# t1023
# t1024
# t1025
# t1026
# t1027
# t1028
# t1029
# t1030
# t1031
# t1032
# t2003
# t2004
# t3002
# t3007
# t3008
# t3009
# t3010
# t4001
# t4002
# t4005
# t4006
# 0.000997304916381836

# %%
# Preparation (TSTM update)
s = time.time()
for k, v in hDict.items():
    v.append("P5")

TC4CA = ["t5001","t5002","t5003","t5004","t5005","t5006"]
hashes = [["64ddae596dd49cbf642565f73118a1469b59d6d030a37473d58f74c6cafc3443"], ["7cc3e9b6d7773f707a7929c0b924bb2f619b18ed6723b39def5bcac99484ec9c"], ["3fa70809476707dee1f9fc4c2f37eed27fdb969c2f3ebdfb12d4f7c8055221e0"], ["9f51f1b63e310d0cff14c2a3512bacd79de071850392009705a30db7642664c2"], ["42af89feb61376642de588eb68dd947878de64e05fa3c8b68d516943ba85766a"], ["7367a5a5e85ab6da9a3fee7cbb0a75ce0842643263b90a8170a263a03ae6a633"]]
for i in range(6):
    hDict[TC4CA[i]] = hashes[i]
    
print(hDict)
e = time.time()
print(e-s)
# Out:
# {'t1001': ['89d21e694ca58e764db12b0d727b531e78e03655495e1ebb9f94bbbef0708be13', 'P5'], 't1002': ['3fa70809476707dee1f9fc4c2f37eed27fdb969c2f3ebdfb12d4f7c8055221e0', 'P5'], 't1003': ['d8b14d7878da2a82378d2d6d790c01d9d206bb13e176376602ff0347e4e75095', 'P5'], 't1004': ['9f51f1b63e310d0cff14c2a3512bacd79de071850392009705a30db7642664c2', 'P5'], 't1005': ['9be770fe5e98fea4a379a13b66cd1c36165d930cc5a6a1584e9bac625ff93d81', 'P5'], 't1006': ['14c30960c8b17993c7da54991af62b79c270b073f0075e58af1d01f4de6ab23d', 'P5'], 't1007': ['89d21394ca58e764db12b0d727b531e78e03655495e1ebb9f94bbbef0708be13', 'P5'], 't1008': ['0180ae596dd49cbf642b5fa73118a1ff9b59d6d030a37473d58f74c6cafccc7f', 'P5'], 't1009': ['6d099b24c6c8573197ee23f5a490a430fea49e7d6912c8bfbf5705d6534ac348', 'P5'], 't1010': ['3fa70809476707dee1f9fc4c2f37eed27fdb969c2f3ebdfb12d4f7c8055221e0', 'P5'], 't1011': ['9f51f1b63e310d0cff14c2a3512bacd79de071850392009705a30db7642664c2', 'P5'], 't1012': ['9be770fe5e98fea4a379a13b66cd1c36165d930cc5a6a1584e9bac625ff93d81', 'P5'], 't1013': ['14c30960c8b17993c7da54991af62b79c270b073f0075e58af1d01f4de6ab23d', 'P5'], 't1014': ['89d21394ca58e764db12b0d727b531e78e03655495e1ebb9f94bbbef0708be13', 'P5'], 't1015': ['0180ae596dd49cbf642b5fa73118a1ff9b59d6d030a37473d58f74c6cafccc7f', 'P5'], 't1021': ['64faae596dd49cbf642565f73118a1469b59d6d030a37473d58f74c6cafc3443', 'P5'], 't1022': ['6d099b24c6c8573197ee23f5a490a430fea49e7d6912c8bfbf5705d6534ac348', 'P5'], 't1023': ['557f384c08c6517e013304cc0501a36b9f615489b072aaae3d3ef2d4fb00faf3', 'P5'], 't1024': ['f3a973adb5aeb504adea824eda7b324ecab7f9d8050ff224aac9285b9212a98a', 'P5'], 't1025': ['7cc3e9b6d7773f707a7929c0b924bb2f619b18ed6723b39def5bcac99484ec9c', 'P5'], 't1026': ['dd92214ff49d5dde577669bed0439a05255d9ab324f116ea870c9aff8eb1b373', 'P5'], 't1027': ['c837f48496fe49c2b40c5c0c8c4d05b68d3128a745446877ad887a1f9bc5a5cf', 'P5'], 't1028': ['5ea52a77cadca7dcad5981cf6a4013e43087965023efdac5108e4e8fbb537ea8', 'P5'], 't1029': ['0e36002b47dff37a6be1de864179fb011c539243afc960812f71ab1d84f315cd', 'P5'], 't1030': ['24d52ce18954f784cada1bf57484dd2a270403fbdd0b62ecc66bb1823e1436f5', 'P5'], 't1031': ['27b790699327188b6118b9fc74fc9e15083e8af06128abdd06afc1ba168d1113', 'P5'], 't1032': ['b11acaa010a45855494a1a4bb00665797767c34320c8a077fef569c82954fee9', 'P5'], 't2001': ['64ddae596dd49cbf642565f73118a1469b59d6d030a37473d58f74c6cafc3443', 'P5'], 't2002': ['6d099b24c6c8573197e553f5a490a430fea49e7d6912c8bfbf5705d6534ac348', 'P5'], 't2003': ['a6181a537629c3eb3ff0d8f69296b299603cdffaac9aa7b4b6b8431d9f89836f', 'P5'], 't2004': ['42af89feb61376642de588eb68dd947878de64e05fa3c8b68d516943ba85766a', 'P5'], 't3001': ['64fa33596dd49cbf642565f73118a1469b59d6d030a37473d58f74c6cafc3443', 'P5'], 't3002': ['7367a5a5e85ab6da9a3fee7cbb0a75ce0842643263b90a8170a263a03ae6a633', 'P5'], 't3003': ['d786b6a9cfe354db661204cb14e1f6c539eaddca70cdd3beb0c54f61382954a1', 'P5'], 't3004': ['9a3fe3d2f83bdc97147e802acb8913354735c2777999c497e1548b0b639d3765', 'P5'], 't3005': ['0e36002b47dff37a6be1de864179fb011c5aa243afc960812f71ab1d84f315cd', 'P5'], 't3006': ['7266386e98c21a363846032c74a443aab5d1ad97a65f07e1d91c6ca8be789122', 'P5'], 't3007': ['1c09a1698cc13773b3e2faff712405f13f633ff943cb2325bb45d658767bfe8c', 'P5'], 't3008': ['438a2b69acd8350590e528b709782892094ddbf3cbe5be0466f63773a4c10d9c', 'P5'], 't3009': ['252e5cb29deb35fbf611c16e1cb30932f0ab6cd2379b24949ce1c7cafa7ce244', 'P5'], 't3010': ['82a523c8cdd1f335c3ad6aa276865b29f9013d1534bf632d66f91ee1e1834805', 'P5'], 't4001': ['1a9996023a3cc1e2f4811c04678f2ef7c5bf56bbf6713383bb8712326194cecd', 'P5'], 't4002': ['382b82ffa1058b6915b754bef2bf86a67c5c78de146abd2b2346e946e9cc5076', 'P5'], 't4003': ['d786b6a9cfe354db661ee4cb14e1f6c539eaddca70cdd3beb0c54f61382954a1', 'P5'], 't4004': ['9a3fe3d2f83bdc97147e802acb8913354115c2777999c497e1548b0b639d3765', 'P5'], 't4005': ['382b82ffa1058b6915b754bef2bf86a67c5c78de146abd2b2346e946e9cc5076', 'P5'], 't4006': ['4159dbbc723bd962ffc6befda35990a28f9b996e09e83093a724cc57107367c1', 'P5'], 't5 ...
# 0.0009806156158447266
